# %%
from nemo_microservices import NeMoMicroservices

# Initialize the client
client = NeMoMicroservices(
    base_url="http://nemo.test",
    inference_base_url="http://nim.test"
)

# List namespaces
namespaces = client.namespaces.list()
print(namespaces.data)
# Out:
# [Namespace(id='default', created_at=datetime.datetime(2026, 1, 17, 1, 47, 20, 933559), custom_fields={}, description=None, ownership=None, project=None, updated_at=datetime.datetime(2026, 1, 17, 1, 47, 20, 933561))]

# %%
import asyncio
from nemo_microservices import AsyncNeMoMicroservices

async def main():
    # Initialize the async client
    client = AsyncNeMoMicroservices(
        base_url="http://nemo.test",
        inference_base_url="http://nim.test"
    )
    
    # List namespaces
    namespaces = await client.namespaces.list()
    print(namespaces.data)

# Run the async function
asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 16
#      13     print(namespaces.data)
#      15 # Run the async function
# ---> 16 asyncio.run(main())
#
# File ~/.pyenv/versions/3.11.14/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
